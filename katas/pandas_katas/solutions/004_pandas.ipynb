# %% [markdown]
# # Pandas
#
# Pandas is a powerful library for data manipulation and analysis in Python. It is widely used in a range of fields, including data science, finance, and statistics.

# %% [markdown]
# ## 004. Iteration

# %% [markdown]
# ## 004.000 Assets
#
# Some assets to avoid too much typing
#
# | Name        | Age|
# |-------------|----|
# | Mbappé      | 23 |
# | De Bruyne   | 31 |
# | Lewandowski | 33 |
# | Benzema     | 34 |
# | Messi       | 35 |

# %%
import sys
from pathlib import Path

current_dir = Path().resolve()
while current_dir != current_dir.parent and current_dir.name != "katas":
    current_dir = current_dir.parent
if current_dir != current_dir.parent:
    sys.path.append(current_dir.as_posix())

# %%
import pandas as pd
from lib.utils import fresh_df
from IPython.core.interactiveshell import InteractiveShell

pd.set_option('display.max_rows', None)
InteractiveShell.ast_node_interactivity = "all"

# %% [markdown]
# ### 004.001 Using Itertuples
#
# 1. Use itertuples to print each row

# %%
df = fresh_df("002.tsv", id="Name")
# solution

for row in df.itertuples():
    print(row)
# Out:
# Pandas(Index='Mbappé', DOB='1998-12-20')
# Pandas(Index='De Bruyne', DOB='1991-06-28')
# Pandas(Index='Lewandowski', DOB='1988-08-21')
# Pandas(Index='Benzema', DOB='1987-12-19')
# Pandas(Index='Messi', DOB='1987-06-24')

# %% [markdown]
# ### 004.002 Using iterrows
#
# 1. Use iterrows to print the index of each row, and then the row as a Series

# %%
df = fresh_df("002.tsv")
# solution

for index, row in df.iterrows():
    index
    row
# Out:
# 0
# Name        Mbappé
# DOB     1998-12-20
# Name: 0, dtype: object
# 1
# Name     De Bruyne
# DOB     1991-06-28
# Name: 1, dtype: object
# 2
# Name    Lewandowski
# DOB      1988-08-21
# Name: 2, dtype: object
# 3
# Name       Benzema
# DOB     1987-12-19
# Name: 3, dtype: object
# 4
# Name         Messi
# DOB     1987-06-24
# Name: 4, dtype: object

# %% [markdown]
# ### 004.003 Using Items
#
# 1. Use items to print each column as a series

# %%
df = fresh_df("002.tsv")
# solution

for index, col in df.items():
    index
    col
# Out:
# 'Name'
# 0         Mbappé
# 1      De Bruyne
# 2    Lewandowski
# 3        Benzema
# 4          Messi
# Name: Name, dtype: object
# 'DOB'
# 0    1998-12-20
# 1    1991-06-28
# 2    1988-08-21
# 3    1987-12-19
# 4    1987-06-24
# Name: DOB, dtype: object

# %% [markdown]
# ### 004.004 Using Query
#
# 1. Add an 'Age' column with years of player
# 1. Use query to find all players older than 30 years
# 1. Make another query for all players older than 30 and with a name longer than 8 characters

# %%
from datetime import datetime
df = fresh_df("002.tsv")
# solution

1
df["Age"] = df.apply(lambda row: (datetime.now() - datetime.strptime(row['DOB'], '%Y-%m-%d')).days // 365, axis=1)

2
df.query("Age > 30")

3
df.query("Age > 30 and Name.str.len() > 8")
# Out:
# 1
# 2
#           Name         DOB  Age
# 1    De Bruyne  1991-06-28   31
# 2  Lewandowski  1988-08-21   34
# 3      Benzema  1987-12-19   35
# 4        Messi  1987-06-24   35
# 3
#           Name         DOB  Age
# 1    De Bruyne  1991-06-28   31
# 2  Lewandowski  1988-08-21   34

# %% [markdown]
# ### 004.003 aggregagtion
#
# 1. Load the minimal_player_list file
# 1. Find the mean, median and max for Age and Wages in the complete datase

# %%
1
datafile = "minimal_player_list.csv"
df = fresh_df(datafile, id="ID", sep=",")
df.head()
# solution

2
df[["Age", "Wage"]].agg(['mean',  'median', 'max'])
# Out:
# 1
#                       Name  Age Nationality  Overall  Potential  \
# ID
# 231747       Kylian Mbappé   23      France       91         95
# 192985     Kevin De Bruyne   31     Belgium       91         91
# 188545  Robert Lewandowski   33      Poland       91         91
# 165153       Karim Benzema   34      France       91         91
# 158023        Lionel Messi   35   Argentina       91         91
#
#                        Club      Value      Wage Position
# ID
# 231747  Paris Saint Germain  190500000  23000000       ST
# 192985      Manchester City  107500000  35000000       CM
# 188545         FC Barcelona   84000000  42000000       ST
# 165153          Real Madrid   64000000  45000000       CF
# 158023  Paris Saint Germain   54000000  19500000       RW
# 2
#               Age          Wage
# mean    26.341552  1.308528e+06
# median  26.000000  5.000000e+05
# max     44.000000  4.500000e+07

# %% [markdown]
# ### 004.005 Using Grouping
#
# 1. Generate a DataFrame with the rows grouped by nationality and for each nationality the max wages. Use `reset_index` to generate the DataFrame. Show its head
# 1. Merge back to the original dataframe, so that the original rows are still with the aggregates. Show its head
# 1. Extract the "Name", "Nationality", and "wage" fields. Show its head
# 1. Sort by Wage descending. Show its head
# 1. Format so that "Wage" has comma separators, and no decimals. Hide its row number. Show its head

# %%
datafile = "minimal_player_list.csv"
df = fresh_df(datafile, id="ID", sep=",")
group_by_field = "Nationality"
# solution
df.head()

1
max_wages = df.groupby([group_by_field])["Wage"].agg('max').reset_index()
max_wages.head()

2 
agg = max_wages.merge(df, on=[group_by_field, "Wage"])
agg.head()

3
agg = df[["Name", group_by_field, "Wage"]]
agg.head()

4
agg = agg.sort_values(by="Wage", ascending=False)[0:20].copy()
agg

4
agg.style.format("{:,.0f}", subset=["Wage"]).hide(axis="index")
# Out:
#                       Name  Age Nationality  Overall  Potential  \
# ID
# 231747       Kylian Mbappé   23      France       91         95
# 192985     Kevin De Bruyne   31     Belgium       91         91
# 188545  Robert Lewandowski   33      Poland       91         91
# 165153       Karim Benzema   34      France       91         91
# 158023        Lionel Messi   35   Argentina       91         91
#
#                        Club      Value      Wage Position
# ID
# 231747  Paris Saint Germain  190500000  23000000       ST
# 192985      Manchester City  107500000  35000000       CM
# 188545         FC Barcelona   84000000  42000000       ST
# 165153          Real Madrid   64000000  45000000       CF
# 158023  Paris Saint Germain   54000000  19500000       RW
# 1
#    Nationality      Wage
# 0  Afghanistan    100000
# 1      Albania   6400000
# 2      Algeria  20000000
# 3      Andorra    300000
# 4       Angola   3400000
# 2
#    Nationality      Wage                               Name  Age  Overall  \
# 0  Afghanistan    100000                      Rahmat Akbari   22       63
# 1      Albania   6400000                      Armando Broja   20       75
# 2      Algeria  20000000                       Riyad Mahrez   31       85
# 3      Andorra    300000             Iker Álvarez de Eulate   20       63
# 4       Angola   3400000  Hélder Wander Sousa Azevedo Costa   28       74
#
#    Potential             Club     Value Position
# 0         68    Brisbane Roar  72500000       CM
# 1         83          Chelsea  12500000       ST
# 2         85  Manchester City  44500000       RW
# 3         74       Villarreal  90000000       GK
# 4         74       Al Ittihad   4200000       RM
# 3
#                       Name Nationality      Wage
# ID
# 231747       Kylian Mbappé      France  23000000
# 192985     Kevin De Bruyne     Belgium  35000000
# 188545  Robert Lewandowski      Poland  42000000
# 165153       Karim Benzema      France  45000000
# 158023        Lionel Messi   Argentina  19500000
# 4
#                                      Name     Nationality      Wage
# ID
# 165153                      Karim Benzema          France  45000000
# 188545                 Robert Lewandowski          Poland  42000000
# 192985                    Kevin De Bruyne         Belgium  35000000
# 182521                         Toni Kroos         Germany  31000000
# 209331                      Mohamed Salah           Egypt  27000000
# 218667     Bernardo Mota Carvalho e Silva        Portugal  26000000
# 205452                    Antonio Rüdiger         Germany  25000000
# 192119                   Thibaut Courtois         Belgium  25000000
# 210514          João Pedro Cavaco Cancelo        Portugal  25000000
# 200145  Carlos Henrique Venancio Casimiro          Brazil  24000000
# 202126                         Harry Kane         England  24000000
# 200104                      Heung Min Son  Korea Republic  24000000
# 202556                      Memphis Depay     Netherlands  23000000
# 228702                    Frenkie de Jong     Netherlands  23000000
# 177003                        Luka Modrić         Croatia  23000000
# 239818       Rúben Santos Gato Alves Dias        Portugal  23000000
# 231747                      Kylian Mbappé          France  23000000
# 239085                     Erling Haaland          Norway  23000000
# 203376                    Virgil van Dijk     Netherlands  22000000
# 197445                        David Alaba         Austria  22000000
# 4
# <style type="text/css">
# </style>
# <table id="T_d8563">
#   <thead>
#     <tr>
#       <th id="T_d8563_level0_col0" class="col_heading level0 col0" >Name</th>
#       <th id="T_d8563_level0_col1" class="col_heading level0 col1" >Nationality</th>
#       <th id="T_d8563_level0_col2" class="col_heading level0 col2" >Wage</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_d8563_row0_col0" class="data row0 col0" >Karim Benzema</td>
#       <td id="T_d8563_row0_col1" class="data row0 col1" >France</td>
#       <td id="T_d8563_row0_col2" class="data row0 col2" >45,000,000</td>
#     </tr>
#     <tr>
#       <td id="T_d8563_row1_col0" class="data row1 col0" >Robert Lewandowski</td>
#       <td id="T_d8563_row1_col1" class="data row1 col1" >Poland</td>
#       <td id="T_d8563_row1_col2" class="data row1 col2" >42,000,000</td>
#     </tr>
#     <tr>
#       <td id="T_d8563_row2_col0" class="data row2 col0" >Kevin De Bruyne</td>
#       <td id="T_d8563_row2_col1" class="data row2 col1" >Belgium</td>
#       <td id="T_d8563_row2_col2" class="data row2 col2" >35,000,000</td>
#     </tr>
#     <tr>
#       <td id="T_d8563_row3_col0" class="data row3 col0" >Toni Kroos</td>
#       <td id="T_d8563_row3_col1" class="data row3 col1" >Germany</td>
#       <td id="T_d8563_row3_col2" class="data row3 col2" >31,000,000</td>
#     </tr>
#     <tr>
#       <td id="T_d8563_row4_col0" class="data row4 col0" >Mohamed Salah</td>
#       <td id="T_d8563_row4_col1" class="data row4 col1" >Egypt</td>
#       <td id="T_d8563_row4_col2" class="data row4 col2" >27,000,000</td>
#     </tr>
#     <tr>
#       <td id="T_d8563_row5_col0" class="data row5 col0" >Bernardo Mota Carvalho e Silva</td>
#       <td id="T_d8563_row5_col1" class="data row5 col1" >Portugal</td>
#       <td id="T_d8563_row5_col2" class="data row5 col2" >26,000,000</td>
#     </tr>
#     <tr>
#       <td id="T_d8563_row6_col0" class="data row6 col0" >Antonio Rüdiger</td>
#       <td id="T_d8563_row6_col1" class="data row6 col1" >Germany</td>
#       <td id="T_d8563_row6_col2" class="data row6 col2" >25,000,000</td>
#     </tr>
#     <tr>
#       <td id="T_d8563_row7_col0" class="data row7 col0" >Thibaut Courtois</td>
#       <td id="T_d8563_row7_col1" class="data row7 col1" >Belgium</td>
#       <td id="T_d8563_row7_col2" class="data row7 col2" >25,000,000</td>
#     </tr>
#     <tr>
#       <td id="T_d8563_row8_col0" class="data row8 col0" >João Pedro Cavaco Cancelo</td>
#       <td id="T_d8563_row8_col1" class="data row8 col1" >Portugal</td>
#       <td id="T_d8563_row8_col2" class="data row8 col2" >25,000,000</td>
#     </tr>
#     <tr>
#       <td id="T_d8563_row9_col0" class="data row9 col0" >Carlos Henrique Venancio Casimiro</td>
#       <td id="T_d8563_row9_col1" class="data row9 col1" >Brazil</td>
#       <td id="T_d8563_row9_col2" class="data row9 col2" >24,000,000</td>
#     </tr>
#     <tr>
#       <td id="T_d8563_row10_col0" class="data row10 col0" >Harry Kane</td>
#       <td id="T_d8563_row10_col1" class="data row10 col1" >England</td>
#       <td id="T_d8563_row10_col2" class="data row10 col2" >24,000,000</td>
#     </tr>
#     <tr>
#       <td id="T_d8563_row11_col0" class="data row11 col0" >Heung Min Son</td>
#       <td id="T_d8563_row11_col1" class="data row11 col1" >Korea Republic</td>
#       <td id="T_d8563_row11_col2" class="data row11 col2" >24,000,000</td>
#     </tr>
#     <tr>
#       <td id="T_d8563_row12_col0" class="data row12 col0" >Memphis Depay</td>
#       <td id="T_d8563_row12_col1" class="data row12 col1" >Netherlands</td>
#       <td id="T_d8563_row12_col2" class="data row12 col2" >23,000,000</td>
#     </tr>
#     <tr>
#       <td id="T_d8563_row13_col0" class="data row13 col0" >Frenkie de Jong</td>
#       <td id="T_d8563_row13_col1" class="data row13 col1" >Netherlands</td>
#       <td id="T_d8563_row13_col2" class="data row13 col2" >23,000,000</td>
#     </tr>
#     <tr>
#       <td id="T_d8563_row14_col0" class="data row14 col0" >Luka Modrić</td>
#       <td id="T_d8563_row14_col1" class="data row14 col1" >Croatia</td>
#       <td id="T_d8563_row14_col2" class="data row14 col2" >23,000,000</td>
#     </tr>
#     <tr>
#       <td id="T_d8563_row15_col0" class="data row15 col0" >Rúben Santos Gato Alves Dias</td>
#       <td id="T_d8563_row15_col1" class="data row15 col1" >Portugal</td>
#       <td id="T_d8563_row15_col2" class="data row15 col2" >23,000,000</td>
#     </tr>
#     <tr>
#       <td id="T_d8563_row16_col0" class="data row16 col0" >Kylian Mbappé</td>
#       <td id="T_d8563_row16_col1" class="data row16 col1" >France</td>
#       <td id="T_d8563_row16_col2" class="data row16 col2" >23,000,000</td>
#     </tr>
#     <tr>
#       <td id="T_d8563_row17_col0" class="data row17 col0" >Erling Haaland</td>
#       <td id="T_d8563_row17_col1" class="data row17 col1" >Norway</td>
#       <td id="T_d8563_row17_col2" class="data row17 col2" >23,000,000</td>
#     </tr>
#     <tr>
#       <td id="T_d8563_row18_col0" class="data row18 col0" >Virgil van Dijk</td>
#       <td id="T_d8563_row18_col1" class="data row18 col1" >Netherlands</td>
#       <td id="T_d8563_row18_col2" class="data row18 col2" >22,000,000</td>
#     </tr>
#     <tr>
#       <td id="T_d8563_row19_col0" class="data row19 col0" >David Alaba</td>
#       <td id="T_d8563_row19_col1" class="data row19 col1" >Austria</td>
#       <td id="T_d8563_row19_col2" class="data row19 col2" >22,000,000</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ### 004.006 Using Grouping
#
# 1. Repeat 004.005, but applied to "Club" instead of "Nationality". Also, it should only apply to players with "Wage > 2000000"
#     1. Generate a DataFrame with the rows grouped by nationality and for each nationality the max wages. Use `reset_index` to generate the DataFrame. Show its head
#     1. Merge back to the original dataframe, so that the original rows are still with the aggregates. Show its head
#     1. Extract the "Name", "Club", and "wage" fields. Show its head
#     1. Sort by Wage descending. Show its head
#     1. Format so that "Wage" has comma separators, and no decimals. Hide its row number. Show its head

# %%
datafile = "minimal_player_list.csv"
df = fresh_df(datafile, id="ID", sep=",")
group_by_field = "Club"
# solution

1
agg = df.query("Wage > 2000000").groupby([group_by_field])["Wage"].max().reset_index()
agg.head()

2
agg = agg.merge(df, on=[group_by_field, "Wage"])
agg.head()


3
agg = agg[["Name", group_by_field, "Wage"]]
agg.head()

4
agg = agg.sort_values(by="Wage", ascending=False)[0:20].copy()
agg

5
agg.style.format("{:,.0f}", subset=["Wage"]).hide(axis="index")
# Out:
# 1
#               Club     Wage
# 0  AFC Bournemouth  4700000
# 1               AZ  2900000
# 2  Adana Demirspor  2300000
# 3          Ajaccio  2200000
# 4             Ajax  4200000
# 2
#               Club     Wage                  Name  Age  Nationality  Overall  \
# 0  AFC Bournemouth  4700000  Norberto Murara Neto   32       Brazil       81
# 1               AZ  2900000      Zinho Vanheusden   22      Belgium       72
# 2  Adana Demirspor  2300000    Yaroslav Rakitskyi   32      Ukraine       78
# 3          Ajaccio  2200000         Youssouf Koné   26         Mali       69
# 4             Ajax  4200000     Mohamed Ihattaren   20  Netherlands       72
#
#    Potential     Value Position
# 0         81  13000000       GK
# 1         79   4400000       CB
# 2         78   9000000       CB
# 3         70   1500000       LB
# 4         77   3500000      CAM
# 3
#                    Name             Club     Wage
# 0  Norberto Murara Neto  AFC Bournemouth  4700000
# 1      Zinho Vanheusden               AZ  2900000
# 2    Yaroslav Rakitskyi  Adana Demirspor  2300000
# 3         Youssouf Koné          Ajaccio  2200000
# 4     Mohamed Ihattaren             Ajax  4200000
# 4
#                                   Name                 Club      Wage
# 150                      Karim Benzema          Real Madrid  45000000
# 65                  Robert Lewandowski         FC Barcelona  42000000
# 120                    Kevin De Bruyne      Manchester City  35000000
# 116                      Mohamed Salah            Liverpool  27000000
# 121  Carlos Henrique Venancio Casimiro    Manchester United  24000000
# 189                      Heung Min Son    Tottenham Hotspur  24000000
# 188                         Harry Kane    Tottenham Hotspur  24000000
# 140                      Kylian Mbappé  Paris Saint Germain  23000000
# 51                        N'Golo Kanté              Chelsea  21000000
# 98                       Romelu Lukaku                Inter  20000000
# 101                       Filip Kostić             Juventus  16500000
# 102                         Paul Pogba             Juventus  16500000
# 66                          Sadio Mané    FC Bayern München  15500000
# 23           Gabriel Fernando de Jesus              Arsenal  13000000
# 157                       Paulo Dybala                 Roma  13000000
# 108                      Samuel Umtiti                Lecce  12500000
# 131                    Kieran Trippier     Newcastle United  12000000
# 110                     James Maddison       Leicester City  11500000
# 111                    Youri Tielemans       Leicester City  11500000
# 167                Alex Nicolao Telles              Sevilla  11000000
# 5
# <style type="text/css">
# </style>
# <table id="T_5667b">
#   <thead>
#     <tr>
#       <th id="T_5667b_level0_col0" class="col_heading level0 col0" >Name</th>
#       <th id="T_5667b_level0_col1" class="col_heading level0 col1" >Club</th>
#       <th id="T_5667b_level0_col2" class="col_heading level0 col2" >Wage</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_5667b_row0_col0" class="data row0 col0" >Karim Benzema</td>
#       <td id="T_5667b_row0_col1" class="data row0 col1" >Real Madrid</td>
#       <td id="T_5667b_row0_col2" class="data row0 col2" >45,000,000</td>
#     </tr>
#     <tr>
#       <td id="T_5667b_row1_col0" class="data row1 col0" >Robert Lewandowski</td>
#       <td id="T_5667b_row1_col1" class="data row1 col1" >FC Barcelona</td>
#       <td id="T_5667b_row1_col2" class="data row1 col2" >42,000,000</td>
#     </tr>
#     <tr>
#       <td id="T_5667b_row2_col0" class="data row2 col0" >Kevin De Bruyne</td>
#       <td id="T_5667b_row2_col1" class="data row2 col1" >Manchester City</td>
#       <td id="T_5667b_row2_col2" class="data row2 col2" >35,000,000</td>
#     </tr>
#     <tr>
#       <td id="T_5667b_row3_col0" class="data row3 col0" >Mohamed Salah</td>
#       <td id="T_5667b_row3_col1" class="data row3 col1" >Liverpool</td>
#       <td id="T_5667b_row3_col2" class="data row3 col2" >27,000,000</td>
#     </tr>
#     <tr>
#       <td id="T_5667b_row4_col0" class="data row4 col0" >Carlos Henrique Venancio Casimiro</td>
#       <td id="T_5667b_row4_col1" class="data row4 col1" >Manchester United</td>
#       <td id="T_5667b_row4_col2" class="data row4 col2" >24,000,000</td>
#     </tr>
#     <tr>
#       <td id="T_5667b_row5_col0" class="data row5 col0" >Heung Min Son</td>
#       <td id="T_5667b_row5_col1" class="data row5 col1" >Tottenham Hotspur</td>
#       <td id="T_5667b_row5_col2" class="data row5 col2" >24,000,000</td>
#     </tr>
#     <tr>
#       <td id="T_5667b_row6_col0" class="data row6 col0" >Harry Kane</td>
#       <td id="T_5667b_row6_col1" class="data row6 col1" >Tottenham Hotspur</td>
#       <td id="T_5667b_row6_col2" class="data row6 col2" >24,000,000</td>
#     </tr>
#     <tr>
#       <td id="T_5667b_row7_col0" class="data row7 col0" >Kylian Mbappé</td>
#       <td id="T_5667b_row7_col1" class="data row7 col1" >Paris Saint Germain</td>
#       <td id="T_5667b_row7_col2" class="data row7 col2" >23,000,000</td>
#     </tr>
#     <tr>
#       <td id="T_5667b_row8_col0" class="data row8 col0" >N'Golo Kanté</td>
#       <td id="T_5667b_row8_col1" class="data row8 col1" >Chelsea</td>
#       <td id="T_5667b_row8_col2" class="data row8 col2" >21,000,000</td>
#     </tr>
#     <tr>
#       <td id="T_5667b_row9_col0" class="data row9 col0" >Romelu Lukaku</td>
#       <td id="T_5667b_row9_col1" class="data row9 col1" >Inter</td>
#       <td id="T_5667b_row9_col2" class="data row9 col2" >20,000,000</td>
#     </tr>
#     <tr>
#       <td id="T_5667b_row10_col0" class="data row10 col0" >Filip Kostić</td>
#       <td id="T_5667b_row10_col1" class="data row10 col1" >Juventus</td>
#       <td id="T_5667b_row10_col2" class="data row10 col2" >16,500,000</td>
#     </tr>
#     <tr>
#       <td id="T_5667b_row11_col0" class="data row11 col0" >Paul Pogba</td>
#       <td id="T_5667b_row11_col1" class="data row11 col1" >Juventus</td>
#       <td id="T_5667b_row11_col2" class="data row11 col2" >16,500,000</td>
#     </tr>
#     <tr>
#       <td id="T_5667b_row12_col0" class="data row12 col0" >Sadio Mané</td>
#       <td id="T_5667b_row12_col1" class="data row12 col1" >FC Bayern München</td>
#       <td id="T_5667b_row12_col2" class="data row12 col2" >15,500,000</td>
#     </tr>
#     <tr>
#       <td id="T_5667b_row13_col0" class="data row13 col0" >Gabriel Fernando de Jesus</td>
#       <td id="T_5667b_row13_col1" class="data row13 col1" >Arsenal</td>
#       <td id="T_5667b_row13_col2" class="data row13 col2" >13,000,000</td>
#     </tr>
#     <tr>
#       <td id="T_5667b_row14_col0" class="data row14 col0" >Paulo Dybala</td>
#       <td id="T_5667b_row14_col1" class="data row14 col1" >Roma</td>
#       <td id="T_5667b_row14_col2" class="data row14 col2" >13,000,000</td>
#     </tr>
#     <tr>
#       <td id="T_5667b_row15_col0" class="data row15 col0" >Samuel Umtiti</td>
#       <td id="T_5667b_row15_col1" class="data row15 col1" >Lecce</td>
#       <td id="T_5667b_row15_col2" class="data row15 col2" >12,500,000</td>
#     </tr>
#     <tr>
#       <td id="T_5667b_row16_col0" class="data row16 col0" >Kieran Trippier</td>
#       <td id="T_5667b_row16_col1" class="data row16 col1" >Newcastle United</td>
#       <td id="T_5667b_row16_col2" class="data row16 col2" >12,000,000</td>
#     </tr>
#     <tr>
#       <td id="T_5667b_row17_col0" class="data row17 col0" >James Maddison</td>
#       <td id="T_5667b_row17_col1" class="data row17 col1" >Leicester City</td>
#       <td id="T_5667b_row17_col2" class="data row17 col2" >11,500,000</td>
#     </tr>
#     <tr>
#       <td id="T_5667b_row18_col0" class="data row18 col0" >Youri Tielemans</td>
#       <td id="T_5667b_row18_col1" class="data row18 col1" >Leicester City</td>
#       <td id="T_5667b_row18_col2" class="data row18 col2" >11,500,000</td>
#     </tr>
#     <tr>
#       <td id="T_5667b_row19_col0" class="data row19 col0" >Alex Nicolao Telles</td>
#       <td id="T_5667b_row19_col1" class="data row19 col1" >Sevilla</td>
#       <td id="T_5667b_row19_col2" class="data row19 col2" >11,000,000</td>
#     </tr>
#   </tbody>
# </table>
