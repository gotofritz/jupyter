# %% [markdown]
# # Pandas
#
# Pandas is a powerful library for data manipulation and analysis in Python. It is widely used in a range of fields, including data science, finance, and statistics.

# %% [markdown]
# ## 006. Preparing csv for anki

# %% [markdown]
# ## 005.000 Assets
#
# "006_4000_words.tsv"
#
# | German               | English              | Plural and inflected forms   | Sample sentence      | Sample sentence Typing Corrects   | Part of Speech   | Audio                |
# |----------------------|----------------------|------------------------------|----------------------|-----------------------------------|------------------|----------------------|
# | nicht                | not                  |                              | Ich kann nicht ko... |                                   | part             | [sound:fa4a14bc-d... |
# | das Jahr             | year                 | die Jahre                    | Das Jahr geht zu ... |                                   | noun             | [sound:325a6575-8... |
# | werden               | to become, get       | wird; wurde; ist ...         | Ich werde müde.      |                                   | verb             | [sound:affec09d-2... |
# | öffentlich           | public               |                              | Die Sitzung des P... | Jan Hus wurde in ...              | adj              | [sound:18a7da24-0... |
# | sich                 | -self                |                              | Sie hat sich im S... |                                   | pron             | [sound:ac72a75d-8... |
# | nicht nur...sonde... | not only...but also  |                              | Diese Kirche ist ... |                                   |                  | [sound:ec47774e-7... |
# | so                   | 1) so, thus, this... |                              | 1) Das musst du s... |                                   | 1) adv; 2) part  | [sound:e13177f4-9... |
# | noch                 | still, yet           |                              | Habt ihr noch Fra... |                                   | adv              | [sound:4a735775-6... |
# | nach                 | after, towards       |                              | Nach dem Mittages... |                                   | prep             | [sound:31b1f293-3... |
# | also                 | so                   |                              | Du hast also kein... |                                   | adv              | [sound:903c7e45-4... |
# | nach und nach        | little by little     |                              | Nach und nach ver... |                                   |                  | [sound:16b55cb8-0... |
# | ihr                  | you (plural, info... |                              | Habt ihr das gewu... | Ist das Ihr Hund?                 | pron             | [sound:6fd5735d-4... |
# | was                  | what                 |                              | Was hast du gesagt?  |                                   | pron             | [sound:97b33d87-f... |
# | dass                 | that                 |                              | Schön, dass Sie k... |                                   | conj             | [sound:ae275fb5-b... |
# | bei                  | by, with, at         |                              | Sie war gestern b... |                                   | prep             | [sound:ccd11177-b... |
# | oder                 | or                   |                              | Möchtest du liebe... |                                   | conj             | [sound:0043eee7-c... |
# | ja                   | yes / certainly      |                              | Ja, ich bin damit... |                                   | part             | [sound:45b5c86b-e... |
# | dann                 | then                 |                              | Dann gehen wir sc... |                                   | adv              | [sound:30fef954-4... |
# | da                   | 1) there; 2) because |                              | 1) Da oben fliegt... |                                   | 1) adv; 2) conj  | [sound:3267a8e2-9... |
# | sein                 | his, its             |                              | Seine Tochter geh... | Ich bin Student.                  | pron             | [sound:0f1dd6c7-e... |

# %%
import sys
from pathlib import Path

current_dir = Path().resolve()
while current_dir != current_dir.parent and current_dir.name != "katas":
    current_dir = current_dir.parent
if current_dir != current_dir.parent:
    sys.path.append(current_dir.as_posix())

# %%
import pandas as pd
import perfplot

from codetiming import Timer

from IPython.core.interactiveshell import InteractiveShell

pd.set_option('display.max_rows', None)
InteractiveShell.ast_node_interactivity = "all"

# %% [markdown]
# ### 006.001 Create the summary above
#
# 1. Read file_4000_words and print the head, bearing in mind that
#    1. it's a tsv file
#    1. the file has no header row; the column names are in cols_4000_words
#    1. empty cells should be an empty string
# 1. Print the first 10 rows of the table in markdown format (github-flavoured tables)
#    1. NOTE: you actually have a print statement
#    1. You should hide the index column
#    1. Create a function that truncates it to 17 characters and adds 3 dots, and use the function that applies it to every cell

# %%
file_4000_words = "006_4000_words.tsv"
cols_4000_words = ["German", "English", "Plural and inflected forms", "Sample sentence", "Sample sentence Typing Corrects", "Part of Speech", "Audio"]
# solution

1
df_4000_words = pd.read_csv(file_4000_words, header=None, sep="\t").fillna("")
df_4000_words.columns = cols_4000_words
df_4000_words.head()

2
truncate_text = lambda text: text[:20-3] + "..." if not isinstance(text, float) and len(text) > 20 else text
df_4000_words = df_4000_words.applymap(truncate_text)
print(df_4000_words[:20].to_markdown(tablefmt="github", index=False))
# Out:
# 1
#        German         English Plural and inflected forms      Sample sentence  \
# 0       nicht             not                             Ich kann nicht k...
# 1    das Jahr            year            die Jahre        Das Jahr geht zu...
# 2      werden  to become, get  wird; wurde; ist...            Ich werde müde.
# 3  öffentlich          public                             Die Sitzung des ...
# 4        sich           -self                             Sie hat sich im ...
#
#   Sample sentence Typing Corrects Part of Speech                Audio
# 0                                           part  [sound:fa4a14bc-...
# 1                                           noun  [sound:325a6575-...
# 2                                           verb  [sound:affec09d-...
# 3  Jan Hus wurde in...                       adj  [sound:18a7da24-...
# 4                                           pron  [sound:ac72a75d-...
# 2
# | German               | English              | Plural and inflected forms   | Sample sentence      | Sample sentence Typing Corrects   | Part of Speech   | Audio                |
# |----------------------|----------------------|------------------------------|----------------------|-----------------------------------|------------------|----------------------|
# | nicht                | not                  |                              | Ich kann nicht ko... |                                   | part             | [sound:fa4a14bc-d... |
# | das Jahr             | year                 | die Jahre                    | Das Jahr geht zu ... |                                   | noun             | [sound:325a6575-8... |
# | werden               | to become, get       | wird; wurde; ist ...         | Ich werde müde.      |                                   | verb             | [sound:affec09d-2... |
# | öffentlich           | public               |                              | Die Sitzung des P... | Jan Hus wurde in ...              | adj              | [sound:18a7da24-0... |
# | sich                 | -self                |                              | Sie hat sich im S... |                                   | pron             | [sound:ac72a75d-8... |
# | nicht nur...sonde... | not only...but also  |                              | Diese Kirche ist ... |                                   |                  | [sound:ec47774e-7... |
# | so                   | 1) so, thus, this... |                              | 1) Das musst du s... |                                   | 1) adv; 2) part  | [sound:e13177f4-9... |
# | noch                 | still, yet           |                              | Habt ihr noch Fra... |                                   | adv              | [sound:4a735775-6... |
# | nach                 | after, towards       |                              | Nach dem Mittages... |                                   | prep             | [sound:31b1f293-3... |
# | also                 | so                   |                              | Du hast also kein... |                                   | adv              | [sound:903c7e45-4... |
# | nach und nach        | little by little     |                              | Nach und nach ver... |                                   |                  | [sound:16b55cb8-0... |
# | ihr                  | you (plural, info... |                              | Habt ihr das gewu... | Ist das Ihr Hund?                 | pron             | [sound:6fd5735d-4... |
# | was                  | what                 |                              | Was hast du gesagt?  |                                   | pron             | [sound:97b33d87-f... |
# | dass                 | that                 |                              | Schön, dass Sie k... |                                   | conj             | [sound:ae275fb5-b... |
# | bei                  | by, with, at         |                              | Sie war gestern b... |                                   | prep             | [sound:ccd11177-b... |
# | oder                 | or                   |                              | Möchtest du liebe... |                                   | conj             | [sound:0043eee7-c... |
# | ja                   | yes / certainly      |                              | Ja, ich bin damit... |                                   | part             | [sound:45b5c86b-e... |
# | dann                 | then                 |                              | Dann gehen wir sc... |                                   | adv              | [sound:30fef954-4... |
# | da                   | 1) there; 2) because |                              | 1) Da oben fliegt... |                                   | 1) adv; 2) conj  | [sound:3267a8e2-9... |
# | sein                 | his, its             |                              | Seine Tochter geh... | Ich bin Student.                  | pron             | [sound:0f1dd6c7-e... |

# %% [markdown]
# ### 006.001 Create the summary above
#
# 1. Read file_4000_words and print the head, bearing in mind that
# 1. Create a new df, `name_article_df`, with two columns; one with the article, if it exists, the other with the noun without the article, or with the complete entry otherwise
#    1. take the "German" column as starting point and use a regular expression to extract the two columns
#    1. Use named column `artikel_d` for the article followed by a space, and `base_d` for the rest of the string, without article if any
#    1. Make sure there are alwwys two column
#    1. Make sure NaN are empty strings
#    1. print head
# 1. Insert `base_d` as 2nd, and `artikel_d` as 4th in `df_4000_words_2`
# 1. Use insert to..
#    1. rename "Plural and inflected forms" to `full_d` and move it to 1st
#    1. rename "English" to `base_e` and move it to 2nd
#    1. Remove both columns and "German"
#    1. rename "Part of Speech" to "pos" and "Audio" to "audio"
# 1. Create 2 new columns, "s1" and "s2", by splitting `Sample sentence` on `2) `
#    1. Make sure "None" columns are actually empty strings
#    1. Remove the "1) " prefix from those columns which have it
#    1. Finally, remove the "Sample sentence" column
# 1. Create a boolean mask for those cells whose string values contains a bracket `)`
#    1. Set the value to ''
#    1. Show the first 20 rows
# 1. Save as tsv to `save_to`

# %%
1
pd.reset_option('display.max_colwidth')
file_4000_words = "006_4000_words.tsv"
cols_4000_words = ["German", "English", "Plural and inflected forms", "Sample sentence", "Sample sentence Typing Corrects", "Part of Speech", "Audio"]
df_4000_words_2 = pd.read_csv(file_4000_words, header=None, sep="\t").fillna("")
df_4000_words_2.columns = cols_4000_words
df_4000_words_2.head()
save_to = "006_4000_words_step_1.tsv"
# solution

2
name_article_df = df_4000_words_2['German'].str.extract(r'^(?P<artikel_d>der\s|die\s|das\s)?(?P<base_d>.+)', expand=True).fillna("")
name_article_df.head()

3
df_4000_words_2.insert(loc=2, column="base_d", value=name_article_df["base_d"])
df_4000_words_2.insert(loc=4, column="artikel_d", value=name_article_df["artikel_d"])
df_4000_words_2.head()

4
df_4000_words_2.insert(loc=0, column="full_d", value=df_4000_words_2["Plural and inflected forms"])
df_4000_words_2.insert(loc=1, column="base_e", value=df_4000_words_2["English"])
df_4000_words_2.rename(columns={"Part of Speech": "pos", "Audio": "audio"}, inplace=True)
df_4000_words_2.drop(columns=["German", "English", "Plural and inflected forms"], inplace=True, axis=1)

5
df_4000_words_2[["s1", "s2"]] = df_4000_words_2["Sample sentence"].str.split(r" 2\)", n=1, expand=True).fillna("")
df_4000_words_2['s1'] = df_4000_words_2['s1'].str.lstrip('1) ')
df_4000_words_2.drop(columns=["Sample sentence"], inplace=True, axis=1)

6
mask = df_4000_words_2["pos"].str.contains(r'\)')
df_4000_words_2.loc[mask, "pos"] = ''
df_4000_words_2[:20]

7
df_4000_words_2.to_csv(save_to, sep="\t", index=False)
# Out:
# 1
#        German         English Plural and inflected forms  \
# 0       nicht             not
# 1    das Jahr            year                  die Jahre
# 2      werden  to become, get  wird; wurde; ist geworden
# 3  öffentlich          public
# 4        sich           -self
#
#                               Sample sentence  \
# 0                      Ich kann nicht kommen.
# 1                      Das Jahr geht zu Ende.
# 2                             Ich werde müde.
# 3  Die Sitzung des Parlaments ist öffentlich.
# 4            Sie hat sich im Spiegel gesehen.
#
#                      Sample sentence Typing Corrects Part of Speech  \
# 0                                                              part
# 1                                                              noun
# 2                                                              verb
# 3  Jan Hus wurde in aller Offentlichkeit hingeric...            adj
# 4                                                              pron
#
#                                               Audio
# 0  [sound:fa4a14bc-d1e9-547a-b29e-ee09ead02804.mp3]
# 1  [sound:325a6575-808e-50ae-b410-a25c98a7bbe4.mp3]
# 2  [sound:affec09d-29f0-541b-926d-e81efc66fa4e.mp3]
# 3  [sound:18a7da24-0dc1-5728-a49f-9c78f28d7937.mp3]
# 4  [sound:ac72a75d-8f61-535a-8378-dc0b61253332.mp3]
# 2
#   artikel_d      base_d
# 0                 nicht
# 1      das         Jahr
# 2                werden
# 3            öffentlich
# 4                  sich
# 3
#        German         English      base_d Plural and inflected forms  \
# 0       nicht             not       nicht
# 1    das Jahr            year        Jahr                  die Jahre
# 2      werden  to become, get      werden  wird; wurde; ist geworden
# 3  öffentlich          public  öffentlich
# 4        sich           -self        sich
#
#   artikel_d                             Sample sentence  \
# 0                                Ich kann nicht kommen.
# 1      das                       Das Jahr geht zu Ende.
# 2                                       Ich werde müde.
# 3            Die Sitzung des Parlaments ist öffentlich.
# 4                      Sie hat sich im Spiegel gesehen.
#
#                      Sample sentence Typing Corrects Part of Speech  \
# 0                                                              part
# 1                                                              noun
# 2                                                              verb
# 3  Jan Hus wurde in aller Offentlichkeit hingeric...            adj
# 4                                                              pron
#
#                                               Audio
# 0  [sound:fa4a14bc-d1e9-547a-b29e-ee09ead02804.mp3]
# 1  [sound:325a6575-808e-50ae-b410-a25c98a7bbe4.mp3]
# 2  [sound:affec09d-29f0-541b-926d-e81efc66fa4e.mp3]
# 3  [sound:18a7da24-0dc1-5728-a49f-9c78f28d7937.mp3]
# 4  [sound:ac72a75d-8f61-535a-8378-dc0b61253332.mp3]
# 4
# 5
# 6
#                        full_d                               base_e  \
# 0                                                              not
# 1                   die Jahre                                 year
# 2   wird; wurde; ist geworden                       to become, get
# 3                                                           public
# 4                                                            -self
# 5                                              not only...but also
# 6                               1) so, thus, this way, such; 2) so
# 7                                                       still, yet
# 8                                                   after, towards
# 9                                                               so
# 10                                                little by little
# 11                             you (plural, informal) / her, their
# 12                                                            what
# 13                                                            that
# 14                                                    by, with, at
# 15                                                              or
# 16                                                 yes / certainly
# 17                                                            then
# 18                                            1) there; 2) because
# 19                                                        his, its
#
#                       base_d artikel_d  \
# 0                      nicht
# 1                       Jahr      das
# 2                     werden
# 3                 öffentlich
# 4                       sich
# 5   nicht nur...sondern auch
# 6                         so
# 7                       noch
# 8                       nach
# 9                       also
# 10             nach und nach
# 11                       ihr
# 12                       was
# 13                      dass
# 14                       bei
# 15                      oder
# 16                        ja
# 17                      dann
# 18                        da
# 19                      sein
#
#                       Sample sentence Typing Corrects   pos  \
# 0                                                      part
# 1                                                      noun
# 2                                                      verb
# 3   Jan Hus wurde in aller Offentlichkeit hingeric...   adj
# 4                                                      pron
# 5
# 6
# 7                                                       adv
# 8                                                      prep
# 9                                                       adv
# 10
# 11                                  Ist das Ihr Hund?  pron
# 12                                                     pron
# 13                                                     conj
# 14                                                     prep
# 15                                                     conj
# 16                                                     part
# 17                                                      adv
# 18
# 19                                   Ich bin Student.  pron
#
#                                                audio  \
# 0   [sound:fa4a14bc-d1e9-547a-b29e-ee09ead02804.mp3]
# 1   [sound:325a6575-808e-50ae-b410-a25c98a7bbe4.mp3]
# 2   [sound:affec09d-29f0-541b-926d-e81efc66fa4e.mp3]
# 3   [sound:18a7da24-0dc1-5728-a49f-9c78f28d7937.mp3]
# 4   [sound:ac72a75d-8f61-535a-8378-dc0b61253332.mp3]
# 5   [sound:ec47774e-7dd2-519f-929b-b80a42a190b2.mp3]
# 6   [sound:e13177f4-93d6-5b3a-87b1-b749ee82c32f.mp3]
# 7   [sound:4a735775-63a0-514b-9d8f-df7dcb25a5f9.mp3]
# 8   [sound:31b1f293-36dd-5d57-83a3-fa246550512c.mp3]
# 9   [sound:903c7e45-4c1b-5885-9e76-0d96348d4169.mp3]
# 10  [sound:16b55cb8-0e3d-5f44-8987-3dad27ae92f5.mp3]
# 11  [sound:6fd5735d-4c43-5ab8-b8db-dae8186419ec.mp3]
# 12  [sound:97b33d87-f367-5170-bdf5-0c615949646f.mp3]
# 13  [sound:ae275fb5-bcc6-53a0-b683-c30964ee5fda.mp3]
# 14  [sound:ccd11177-b639-5d66-9056-cf35d50ff64f.mp3]
# 15  [sound:0043eee7-cea9-5670-9eb0-5f76248404e4.mp3]
# 16  [sound:45b5c86b-e77c-51d8-948e-fa79a66186fd.mp3]
# 17  [sound:30fef954-4663-5e54-8072-a15ad000da05.mp3]
# 18  [sound:3267a8e2-9419-598f-a58d-ba0fafccffc7.mp3]
# 19  [sound:0f1dd6c7-e77f-5601-8762-9804b38e5b61.mp3]
#
#                                                    s1  \
# 0                              Ich kann nicht kommen.
# 1                              Das Jahr geht zu Ende.
# 2                                     Ich werde müde.
# 3          Die Sitzung des Parlaments ist öffentlich.
# 4                    Sie hat sich im Spiegel gesehen.
# 5   Diese Kirche ist nicht nur an Festtagen, sonde...
# 6                             Das musst du so machen.
# 7                               Habt ihr noch Fragen?
# 8           Nach dem Mittagessen gehen wir spazieren.
# 9                            Du hast also keine Zeit.
# 10                   Nach und nach verschwinden alle.
# 11                              Habt ihr das gewusst?
# 12                                Was hast du gesagt?
# 13                            Schön, dass Sie kommen!
# 14                     Sie war gestern beim Zahnarzt.
# 15      Möchtest du lieber Spaghetti oder Tortellini?
# 16                   Ja, ich bin damit einverstanden.
# 17                          Dann gehen wir schwimmen.
# 18                          Da oben fliegt ein Adler.
# 19               Seine Tochter geht schon zur Schule.
#
#                                                    s2
# 0
# 1
# 2
# 3
# 4
# 5
# 6                           Der Kuchen ist so lecker.
# 7
# 8
# 9
# 10
# 11                                   Ich höre ihr zu.
# 12
# 13
# 14
# 15
# 16                                Das ist ja komisch.
# 17
# 18   Da ich nichts von dem Treffen wusste, konnte ...
# 19
# 7
