# %% [markdown]
# # Pandas
#
# Pandas is a powerful library for data manipulation and analysis in Python. It is widely used in a range of fields, including data science, finance, and statistics.

# %% [markdown]
# ## 004. Iteration

# %% [markdown]
# ## 004.000 Assets
#
# Some assets to avoid too much typing
#
# | Name        | Age|
# |-------------|----|
# | Mbappé      | 23 |
# | De Bruyne   | 31 |
# | Lewandowski | 33 |
# | Benzema     | 34 |
# | Messi       | 35 |

# %%
import sys
from pathlib import Path

current_dir = Path().resolve()
while current_dir != current_dir.parent and current_dir.name != "katas":
    current_dir = current_dir.parent
if current_dir != current_dir.parent:
    sys.path.append(current_dir.as_posix())

# %%
import pandas as pd
from lib.utils import fresh_df
from IPython.core.interactiveshell import InteractiveShell

pd.set_option('display.max_rows', None)
InteractiveShell.ast_node_interactivity = "all"

# %% [markdown]
# ### 004.001 Using Itertuples
#
# 1. Use itertuples to print each row

# %%
df = fresh_df("002.tsv", id="Name")
# solution
# Out:
# Pandas(Index='Mbappé', DOB='1998-12-20')
# Pandas(Index='De Bruyne', DOB='1991-06-28')
# Pandas(Index='Lewandowski', DOB='1988-08-21')
# Pandas(Index='Benzema', DOB='1987-12-19')
# Pandas(Index='Messi', DOB='1987-06-24')

# %% [markdown]
# ### 004.002 Using iterrows
#
# 1. Use iterrows to print the index of each row, and then the row as a Series

# %%
df = fresh_df("002.tsv")
# solution
# Out:
# 0
# Name        Mbappé
# DOB     1998-12-20
# Name: 0, dtype: object
# 1
# Name     De Bruyne
# DOB     1991-06-28
# Name: 1, dtype: object
# 2
# Name    Lewandowski
# DOB      1988-08-21
# Name: 2, dtype: object
# 3
# Name       Benzema
# DOB     1987-12-19
# Name: 3, dtype: object
# 4
# Name         Messi
# DOB     1987-06-24
# Name: 4, dtype: object

# %% [markdown]
# ### 004.003 Using Items
#
# 1. Use items to print each column as a series

# %%
df = fresh_df("002.tsv")
# solution
# Out:
# 'Name'
# 0         Mbappé
# 1      De Bruyne
# 2    Lewandowski
# 3        Benzema
# 4          Messi
# Name: Name, dtype: object
# 'DOB'
# 0    1998-12-20
# 1    1991-06-28
# 2    1988-08-21
# 3    1987-12-19
# 4    1987-06-24
# Name: DOB, dtype: object

# %% [markdown]
# ### 004.004 Using Query
#
# 1. Add an 'Age' column with years of player
# 1. Use query to find all players older than 30 years
# 1. Make another query for all players older than 30 and with a name longer than 8 characters

# %%
from datetime import datetime
df = fresh_df("002.tsv")
# solution
# Out:
# 1
# 2
#           Name         DOB  Age
# 1    De Bruyne  1991-06-28   31
# 2  Lewandowski  1988-08-21   34
# 3      Benzema  1987-12-19   35
# 4        Messi  1987-06-24   35
# 3
#           Name         DOB  Age
# 1    De Bruyne  1991-06-28   31
# 2  Lewandowski  1988-08-21   34

# %% [markdown]
# ### 004.003 aggregagtion
#
# 1. Load the minimal_player_list file
# 1. Find the mean, median and max for Age and Wages in the complete datase

# %%
1
datafile = "minimal_player_list.csv"
df = fresh_df(datafile, id="ID", sep=",")
df.head()
# solution
# Out:
# 1
#                       Name  Age Nationality  Overall  Potential  \
# ID
# 231747       Kylian Mbappé   23      France       91         95
# 192985     Kevin De Bruyne   31     Belgium       91         91
# 188545  Robert Lewandowski   33      Poland       91         91
# 165153       Karim Benzema   34      France       91         91
# 158023        Lionel Messi   35   Argentina       91         91
#
#                        Club      Value      Wage Position
# ID
# 231747  Paris Saint Germain  190500000  23000000       ST
# 192985      Manchester City  107500000  35000000       CM
# 188545         FC Barcelona   84000000  42000000       ST
# 165153          Real Madrid   64000000  45000000       CF
# 158023  Paris Saint Germain   54000000  19500000       RW
# 2
#               Age          Wage
# mean    26.341552  1.308528e+06
# median  26.000000  5.000000e+05
# max     44.000000  4.500000e+07

# %% [markdown]
# ### 004.005 Using Grouping
#
# 1. Generate a DataFrame with the rows grouped by nationality and for each nationality the max wages. Use `reset_index` to generate the DataFrame. Show its head
# 1. Merge back to the original dataframe, so that the original rows are still with the aggregates. Show its head
# 1. Extract the "Name", "nationality", and "wage" fields. Show its head
# 1. Sort by Wage descending. Show its head
# 1. Format so that "Wage" has comma separators, and no decimals. Show its head

# %%
datafile = "minimal_player_list.csv"
df = fresh_df(datafile, id="ID", sep=",")
group_by_field = "Nationality"
# solution
# Out:
#                       Name  Age Nationality  Overall  Potential  \
# ID
# 231747       Kylian Mbappé   23      France       91         95
# 192985     Kevin De Bruyne   31     Belgium       91         91
# 188545  Robert Lewandowski   33      Poland       91         91
# 165153       Karim Benzema   34      France       91         91
# 158023        Lionel Messi   35   Argentina       91         91
#
#                        Club      Value      Wage Position
# ID
# 231747  Paris Saint Germain  190500000  23000000       ST
# 192985      Manchester City  107500000  35000000       CM
# 188545         FC Barcelona   84000000  42000000       ST
# 165153          Real Madrid   64000000  45000000       CF
# 158023  Paris Saint Germain   54000000  19500000       RW
# 1
#    Nationality      Wage
# 0  Afghanistan    100000
# 1      Albania   6400000
# 2      Algeria  20000000
# 3      Andorra    300000
# 4       Angola   3400000
# 2
#    Nationality      Wage                               Name  Age  Overall  \
# 0  Afghanistan    100000                      Rahmat Akbari   22       63
# 1      Albania   6400000                      Armando Broja   20       75
# 2      Algeria  20000000                       Riyad Mahrez   31       85
# 3      Andorra    300000             Iker Álvarez de Eulate   20       63
# 4       Angola   3400000  Hélder Wander Sousa Azevedo Costa   28       74
#
#    Potential             Club     Value Position
# 0         68    Brisbane Roar  72500000       CM
# 1         83          Chelsea  12500000       ST
# 2         85  Manchester City  44500000       RW
# 3         74       Villarreal  90000000       GK
# 4         74       Al Ittihad   4200000       RM
# 3
#                       Name Nationality      Wage
# ID
# 231747       Kylian Mbappé      France  23000000
# 192985     Kevin De Bruyne     Belgium  35000000
# 188545  Robert Lewandowski      Poland  42000000
# 165153       Karim Benzema      France  45000000
# 158023        Lionel Messi   Argentina  19500000
# 4
#                       Name Nationality      Wage
# ID
# 165153       Karim Benzema      France  45000000
# 188545  Robert Lewandowski      Poland  42000000
# 192985     Kevin De Bruyne     Belgium  35000000
# 182521          Toni Kroos     Germany  31000000
# 209331       Mohamed Salah       Egypt  27000000
# 4
# <style type="text/css">
# </style>
# <table id="T_84220">
#   <thead>
#     <tr>
#       <th id="T_84220_level0_col0" class="col_heading level0 col0" >Name</th>
#       <th id="T_84220_level0_col1" class="col_heading level0 col1" >Nationality</th>
#       <th id="T_84220_level0_col2" class="col_heading level0 col2" >Wage</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_84220_row0_col0" class="data row0 col0" >Karim Benzema</td>
#       <td id="T_84220_row0_col1" class="data row0 col1" >France</td>
#       <td id="T_84220_row0_col2" class="data row0 col2" >45,000,000</td>
#     </tr>
#     <tr>
#       <td id="T_84220_row1_col0" class="data row1 col0" >Robert Lewandowski</td>
#       <td id="T_84220_row1_col1" class="data row1 col1" >Poland</td>
#       <td id="T_84220_row1_col2" class="data row1 col2" >42,000,000</td>
#     </tr>
#     <tr>
#       <td id="T_84220_row2_col0" class="data row2 col0" >Kevin De Bruyne</td>
#       <td id="T_84220_row2_col1" class="data row2 col1" >Belgium</td>
#       <td id="T_84220_row2_col2" class="data row2 col2" >35,000,000</td>
#     </tr>
#     <tr>
#       <td id="T_84220_row3_col0" class="data row3 col0" >Toni Kroos</td>
#       <td id="T_84220_row3_col1" class="data row3 col1" >Germany</td>
#       <td id="T_84220_row3_col2" class="data row3 col2" >31,000,000</td>
#     </tr>
#     <tr>
#       <td id="T_84220_row4_col0" class="data row4 col0" >Mohamed Salah</td>
#       <td id="T_84220_row4_col1" class="data row4 col1" >Egypt</td>
#       <td id="T_84220_row4_col2" class="data row4 col2" >27,000,000</td>
#     </tr>
#     <tr>
#       <td id="T_84220_row5_col0" class="data row5 col0" >Bernardo Mota Carvalho e Silva</td>
#       <td id="T_84220_row5_col1" class="data row5 col1" >Portugal</td>
#       <td id="T_84220_row5_col2" class="data row5 col2" >26,000,000</td>
#     </tr>
#     <tr>
#       <td id="T_84220_row6_col0" class="data row6 col0" >Antonio Rüdiger</td>
#       <td id="T_84220_row6_col1" class="data row6 col1" >Germany</td>
#       <td id="T_84220_row6_col2" class="data row6 col2" >25,000,000</td>
#     </tr>
#     <tr>
#       <td id="T_84220_row7_col0" class="data row7 col0" >Thibaut Courtois</td>
#       <td id="T_84220_row7_col1" class="data row7 col1" >Belgium</td>
#       <td id="T_84220_row7_col2" class="data row7 col2" >25,000,000</td>
#     </tr>
#     <tr>
#       <td id="T_84220_row8_col0" class="data row8 col0" >João Pedro Cavaco Cancelo</td>
#       <td id="T_84220_row8_col1" class="data row8 col1" >Portugal</td>
#       <td id="T_84220_row8_col2" class="data row8 col2" >25,000,000</td>
#     </tr>
#     <tr>
#       <td id="T_84220_row9_col0" class="data row9 col0" >Carlos Henrique Venancio Casimiro</td>
#       <td id="T_84220_row9_col1" class="data row9 col1" >Brazil</td>
#       <td id="T_84220_row9_col2" class="data row9 col2" >24,000,000</td>
#     </tr>
#     <tr>
#       <td id="T_84220_row10_col0" class="data row10 col0" >Harry Kane</td>
#       <td id="T_84220_row10_col1" class="data row10 col1" >England</td>
#       <td id="T_84220_row10_col2" class="data row10 col2" >24,000,000</td>
#     </tr>
#     <tr>
#       <td id="T_84220_row11_col0" class="data row11 col0" >Heung Min Son</td>
#       <td id="T_84220_row11_col1" class="data row11 col1" >Korea Republic</td>
#       <td id="T_84220_row11_col2" class="data row11 col2" >24,000,000</td>
#     </tr>
#     <tr>
#       <td id="T_84220_row12_col0" class="data row12 col0" >Memphis Depay</td>
#       <td id="T_84220_row12_col1" class="data row12 col1" >Netherlands</td>
#       <td id="T_84220_row12_col2" class="data row12 col2" >23,000,000</td>
#     </tr>
#     <tr>
#       <td id="T_84220_row13_col0" class="data row13 col0" >Frenkie de Jong</td>
#       <td id="T_84220_row13_col1" class="data row13 col1" >Netherlands</td>
#       <td id="T_84220_row13_col2" class="data row13 col2" >23,000,000</td>
#     </tr>
#     <tr>
#       <td id="T_84220_row14_col0" class="data row14 col0" >Luka Modrić</td>
#       <td id="T_84220_row14_col1" class="data row14 col1" >Croatia</td>
#       <td id="T_84220_row14_col2" class="data row14 col2" >23,000,000</td>
#     </tr>
#     <tr>
#       <td id="T_84220_row15_col0" class="data row15 col0" >Rúben Santos Gato Alves Dias</td>
#       <td id="T_84220_row15_col1" class="data row15 col1" >Portugal</td>
#       <td id="T_84220_row15_col2" class="data row15 col2" >23,000,000</td>
#     </tr>
#     <tr>
#       <td id="T_84220_row16_col0" class="data row16 col0" >Kylian Mbappé</td>
#       <td id="T_84220_row16_col1" class="data row16 col1" >France</td>
#       <td id="T_84220_row16_col2" class="data row16 col2" >23,000,000</td>
#     </tr>
#     <tr>
#       <td id="T_84220_row17_col0" class="data row17 col0" >Erling Haaland</td>
#       <td id="T_84220_row17_col1" class="data row17 col1" >Norway</td>
#       <td id="T_84220_row17_col2" class="data row17 col2" >23,000,000</td>
#     </tr>
#     <tr>
#       <td id="T_84220_row18_col0" class="data row18 col0" >Virgil van Dijk</td>
#       <td id="T_84220_row18_col1" class="data row18 col1" >Netherlands</td>
#       <td id="T_84220_row18_col2" class="data row18 col2" >22,000,000</td>
#     </tr>
#     <tr>
#       <td id="T_84220_row19_col0" class="data row19 col0" >David Alaba</td>
#       <td id="T_84220_row19_col1" class="data row19 col1" >Austria</td>
#       <td id="T_84220_row19_col2" class="data row19 col2" >22,000,000</td>
#     </tr>
#     <tr>
#       <td id="T_84220_row20_col0" class="data row20 col0" >Eden Hazard</td>
#       <td id="T_84220_row20_col1" class="data row20 col1" >Belgium</td>
#       <td id="T_84220_row20_col2" class="data row20 col2" >22,000,000</td>
#     </tr>
#     <tr>
#       <td id="T_84220_row21_col0" class="data row21 col0" >C. Ronaldo dos Santos Aveiro</td>
#       <td id="T_84220_row21_col1" class="data row21 col1" >Portugal</td>
#       <td id="T_84220_row21_col2" class="data row21 col2" >21,000,000</td>
#     </tr>
#     <tr>
#       <td id="T_84220_row22_col0" class="data row22 col0" >N'Golo Kanté</td>
#       <td id="T_84220_row22_col1" class="data row22 col1" >France</td>
#       <td id="T_84220_row22_col2" class="data row22 col2" >21,000,000</td>
#     </tr>
#     <tr>
#       <td id="T_84220_row23_col0" class="data row23 col0" >Ederson Santana de Moraes</td>
#       <td id="T_84220_row23_col1" class="data row23 col1" >Brazil</td>
#       <td id="T_84220_row23_col2" class="data row23 col2" >21,000,000</td>
#     </tr>
#     <tr>
#       <td id="T_84220_row24_col0" class="data row24 col0" >Marc-André ter Stegen</td>
#       <td id="T_84220_row24_col1" class="data row24 col1" >Germany</td>
#       <td id="T_84220_row24_col2" class="data row24 col2" >21,000,000</td>
#     </tr>
#     <tr>
#       <td id="T_84220_row25_col0" class="data row25 col0" >Riyad Mahrez</td>
#       <td id="T_84220_row25_col1" class="data row25 col1" >Algeria</td>
#       <td id="T_84220_row25_col2" class="data row25 col2" >20,000,000</td>
#     </tr>
#     <tr>
#       <td id="T_84220_row26_col0" class="data row26 col0" >Rodrigo Hernández Cascante</td>
#       <td id="T_84220_row26_col1" class="data row26 col1" >Spain</td>
#       <td id="T_84220_row26_col2" class="data row26 col2" >20,000,000</td>
#     </tr>
#     <tr>
#       <td id="T_84220_row27_col0" class="data row27 col0" >Neymar da Silva Santos Jr.</td>
#       <td id="T_84220_row27_col1" class="data row27 col1" >Brazil</td>
#       <td id="T_84220_row27_col2" class="data row27 col2" >20,000,000</td>
#     </tr>
#     <tr>
#       <td id="T_84220_row28_col0" class="data row28 col0" >Vinícius José de Oliveira Júnior</td>
#       <td id="T_84220_row28_col1" class="data row28 col1" >Brazil</td>
#       <td id="T_84220_row28_col2" class="data row28 col2" >20,000,000</td>
#     </tr>
#     <tr>
#       <td id="T_84220_row29_col0" class="data row29 col0" >Romelu Lukaku</td>
#       <td id="T_84220_row29_col1" class="data row29 col1" >Belgium</td>
#       <td id="T_84220_row29_col2" class="data row29 col2" >20,000,000</td>
#     </tr>
#     <tr>
#       <td id="T_84220_row30_col0" class="data row30 col0" >Marco Asensio Willemsen</td>
#       <td id="T_84220_row30_col1" class="data row30 col1" >Spain</td>
#       <td id="T_84220_row30_col2" class="data row30 col2" >20,000,000</

# %% [markdown]
# ### 004.006 Using Grouping
#
# 1. Repeat 004.005, but applied to "Club" instead of "Nationality"
# 1. Also, it should only apply to players with "Wage > 2000000"

# %%
datafile = "minimal_player_list.csv"
df = fresh_df(datafile, id="ID", sep=",")
group_by_field = "Club"
# solution
# Out:
# <style type="text/css">
# </style>
# <table id="T_53327">
#   <thead>
#     <tr>
#       <th id="T_53327_level0_col0" class="col_heading level0 col0" >Name</th>
#       <th id="T_53327_level0_col1" class="col_heading level0 col1" >Club</th>
#       <th id="T_53327_level0_col2" class="col_heading level0 col2" >Wage</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_53327_row0_col0" class="data row0 col0" >Karim Benzema</td>
#       <td id="T_53327_row0_col1" class="data row0 col1" >Real Madrid</td>
#       <td id="T_53327_row0_col2" class="data row0 col2" >45,000,000</td>
#     </tr>
#     <tr>
#       <td id="T_53327_row1_col0" class="data row1 col0" >Robert Lewandowski</td>
#       <td id="T_53327_row1_col1" class="data row1 col1" >FC Barcelona</td>
#       <td id="T_53327_row1_col2" class="data row1 col2" >42,000,000</td>
#     </tr>
#     <tr>
#       <td id="T_53327_row2_col0" class="data row2 col0" >Kevin De Bruyne</td>
#       <td id="T_53327_row2_col1" class="data row2 col1" >Manchester City</td>
#       <td id="T_53327_row2_col2" class="data row2 col2" >35,000,000</td>
#     </tr>
#     <tr>
#       <td id="T_53327_row3_col0" class="data row3 col0" >Mohamed Salah</td>
#       <td id="T_53327_row3_col1" class="data row3 col1" >Liverpool</td>
#       <td id="T_53327_row3_col2" class="data row3 col2" >27,000,000</td>
#     </tr>
#     <tr>
#       <td id="T_53327_row4_col0" class="data row4 col0" >Carlos Henrique Venancio Casimiro</td>
#       <td id="T_53327_row4_col1" class="data row4 col1" >Manchester United</td>
#       <td id="T_53327_row4_col2" class="data row4 col2" >24,000,000</td>
#     </tr>
#     <tr>
#       <td id="T_53327_row5_col0" class="data row5 col0" >Heung Min Son</td>
#       <td id="T_53327_row5_col1" class="data row5 col1" >Tottenham Hotspur</td>
#       <td id="T_53327_row5_col2" class="data row5 col2" >24,000,000</td>
#     </tr>
#     <tr>
#       <td id="T_53327_row6_col0" class="data row6 col0" >Harry Kane</td>
#       <td id="T_53327_row6_col1" class="data row6 col1" >Tottenham Hotspur</td>
#       <td id="T_53327_row6_col2" class="data row6 col2" >24,000,000</td>
#     </tr>
#     <tr>
#       <td id="T_53327_row7_col0" class="data row7 col0" >Kylian Mbappé</td>
#       <td id="T_53327_row7_col1" class="data row7 col1" >Paris Saint Germain</td>
#       <td id="T_53327_row7_col2" class="data row7 col2" >23,000,000</td>
#     </tr>
#     <tr>
#       <td id="T_53327_row8_col0" class="data row8 col0" >N'Golo Kanté</td>
#       <td id="T_53327_row8_col1" class="data row8 col1" >Chelsea</td>
#       <td id="T_53327_row8_col2" class="data row8 col2" >21,000,000</td>
#     </tr>
#     <tr>
#       <td id="T_53327_row9_col0" class="data row9 col0" >Romelu Lukaku</td>
#       <td id="T_53327_row9_col1" class="data row9 col1" >Inter</td>
#       <td id="T_53327_row9_col2" class="data row9 col2" >20,000,000</td>
#     </tr>
#     <tr>
#       <td id="T_53327_row10_col0" class="data row10 col0" >Filip Kostić</td>
#       <td id="T_53327_row10_col1" class="data row10 col1" >Juventus</td>
#       <td id="T_53327_row10_col2" class="data row10 col2" >16,500,000</td>
#     </tr>
#     <tr>
#       <td id="T_53327_row11_col0" class="data row11 col0" >Paul Pogba</td>
#       <td id="T_53327_row11_col1" class="data row11 col1" >Juventus</td>
#       <td id="T_53327_row11_col2" class="data row11 col2" >16,500,000</td>
#     </tr>
#     <tr>
#       <td id="T_53327_row12_col0" class="data row12 col0" >Sadio Mané</td>
#       <td id="T_53327_row12_col1" class="data row12 col1" >FC Bayern München</td>
#       <td id="T_53327_row12_col2" class="data row12 col2" >15,500,000</td>
#     </tr>
#     <tr>
#       <td id="T_53327_row13_col0" class="data row13 col0" >Gabriel Fernando de Jesus</td>
#       <td id="T_53327_row13_col1" class="data row13 col1" >Arsenal</td>
#       <td id="T_53327_row13_col2" class="data row13 col2" >13,000,000</td>
#     </tr>
#     <tr>
#       <td id="T_53327_row14_col0" class="data row14 col0" >Paulo Dybala</td>
#       <td id="T_53327_row14_col1" class="data row14 col1" >Roma</td>
#       <td id="T_53327_row14_col2" class="data row14 col2" >13,000,000</td>
#     </tr>
#     <tr>
#       <td id="T_53327_row15_col0" class="data row15 col0" >Samuel Umtiti</td>
#       <td id="T_53327_row15_col1" class="data row15 col1" >Lecce</td>
#       <td id="T_53327_row15_col2" class="data row15 col2" >12,500,000</td>
#     </tr>
#     <tr>
#       <td id="T_53327_row16_col0" class="data row16 col0" >Kieran Trippier</td>
#       <td id="T_53327_row16_col1" class="data row16 col1" >Newcastle United</td>
#       <td id="T_53327_row16_col2" class="data row16 col2" >12,000,000</td>
#     </tr>
#     <tr>
#       <td id="T_53327_row17_col0" class="data row17 col0" >James Maddison</td>
#       <td id="T_53327_row17_col1" class="data row17 col1" >Leicester City</td>
#       <td id="T_53327_row17_col2" class="data row17 col2" >11,500,000</td>
#     </tr>
#     <tr>
#       <td id="T_53327_row18_col0" class="data row18 col0" >Youri Tielemans</td>
#       <td id="T_53327_row18_col1" class="data row18 col1" >Leicester City</td>
#       <td id="T_53327_row18_col2" class="data row18 col2" >11,500,000</td>
#     </tr>
#     <tr>
#       <td id="T_53327_row19_col0" class="data row19 col0" >Alex Nicolao Telles</td>
#       <td id="T_53327_row19_col1" class="data row19 col1" >Sevilla</td>
#       <td id="T_53327_row19_col2" class="data row19 col2" >11,000,000</td>
#     </tr>
#     <tr>
#       <td id="T_53327_row20_col0" class="data row20 col0" >Brahim Díaz</td>
#       <td id="T_53327_row20_col1" class="data row20 col1" >Milan</td>
#       <td id="T_53327_row20_col2" class="data row20 col2" >11,000,000</td>
#     </tr>
#     <tr>
#       <td id="T_53327_row21_col0" class="data row21 col0" >Diego Carlos Santos Silva</td>
#       <td id="T_53327_row21_col1" class="data row21 col1" >Aston Villa</td>
#       <td id="T_53327_row21_col2" class="data row21 col2" >10,500,000</td>
#     </tr>
#     <tr>
#       <td id="T_53327_row22_col0" class="data row22 col0" >Rúben Diogo da Silva Neves</td>
#       <td id="T_53327_row22_col1" class="data row22 col1" >Wolverhampton Wanderers</td>
#       <td id="T_53327_row22_col2" class="data row22 col2" >10,500,000</td>
#     </tr>
#     <tr>
#       <td id="T_53327_row23_col0" class="data row23 col0" >Gonçalo Manuel Ganchinho Guedes</td>
#       <td id="T_53327_row23_col1" class="data row23 col1" >Wolverhampton Wanderers</td>
#       <td id="T_53327_row23_col2" class="data row23 col2" >10,500,000</td>
#     </tr>
#     <tr>
#       <td id="T_53327_row24_col0" class="data row24 col0" >Ciro Immobile</td>
#       <td id="T_53327_row24_col1" class="data row24 col1" >Lazio</td>
#       <td id="T_53327_row24_col2" class="data row24 col2" >10,000,000</td>
#     </tr>
#     <tr>
#       <td id="T_53327_row25_col0" class="data row25 col0" >Giovani Lo Celso</td>
#       <td id="T_53327_row25_col1" class="data row25 col1" >Villarreal</td>
#       <td id="T_53327_row25_col2" class="data row25 col2" >10,000,000</td>
#     </tr>
#     <tr>
#       <td id="T_53327_row26_col0" class="data row26 col0" >Jan Oblak</td>
#       <td id="T_53327_row26_col1" class="data row26 col1" >Atlético Madrid</td>
#       <td id="T_53327_row26_col2" class="data row26 col2" >10,000,000</td>
#     </tr>
#     <tr>
#       <td id="T_53327_row27_col0" class="data row27 col0" >Francisco Mota Castro Trincão</td>
#       <td id="T_53327_row27_col1" class="data row27 col1" >Sporting CP</td>
#       <td id="T_53327_row27_col2" class="data row27 col2" >9,500,000</td>
#     </tr>
#     <tr>
#       <td id="T_53327_row28_col0" class="data row28 col0" >Christopher Nkunku</td>
#       <td id="T_53327_row28_col1" class="data row28 col1" >RB Leipzig</td>
#       <td id="T_53327_row28_col2" class="data row28 col2" >9,000,000</td>
#     </tr>
#     <tr>
#       <td id="T_53327_row29_col0" class="data row29 col0" >Julian Draxler</td>
#       <td id="T_53327_row29_col1" class="data row29 col1" >Benfica</td>
#       <td id="T_53327_row29_col2" class="data row29 col2" >8,800,000</td>
#     </tr>
#     <tr>
#       <td id="T_53327_row30_col0" class="data row30 col0" >Alexandre Lacazette</td>
#       <td id="T_53327_row30_col1" class="data row30 col1" >Olympique Lyon
