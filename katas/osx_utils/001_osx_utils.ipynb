# %% [markdown]
# # CLI UTILS
#
# Just some useful utilities

# %% [markdown]
# ## 001. General OS X utils
#
# Here are things like screenshots, etc

# %%
InteractiveShell.ast_node_interactivity = "all"

# %% [markdown]
# ### 001.001 Video screenshot, OS X
#
# There is a CLI util to take (animated) screen shots of any app window. Make sure your terminal is not full screen
#
# 1. Install the app if needed
# 1. See what windows are available
# 1. Take a screenshot of this window ("Code - Insiders")
# 1. Start Firefox with a random video, https://ytroulette.com/
#     1. and press play (manually)
#     1. and go full screen (manually)
# 1. Record video

# %%
# solution
